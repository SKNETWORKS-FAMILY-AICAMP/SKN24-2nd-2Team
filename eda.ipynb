# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/okcupid_preprocessed.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59934 entries, 0 to 59933
# Data columns (total 44 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  59934 non-null  int64
#  1   sex                         59934 non-null  int64
#  2   orientation                 59934 non-null  int64
#  3   drugs                       59934 non-null  int64
#  4   education                   53310 non-null  float64
#  5   height                      59934 non-null  float64
#  6   job                         51739 non-null  object
#  7   last_online                 59934 non-null  object
#  8   sign                        59934 non-null  int64
#  9   age                         59934 non-null  int64
#  10  status                      59934 non-null  object
#  11  diet                        35547 non-null  object
#  12  location                    59934 non-null  object
#  13  pets                        40018 non-null  object
#  14  body_type_average           59934 non-null  bool
#  15  body_type_curvy             59934 non-null  bool
#  16  body_type_fit               59934 non-null  bool
#  17  body_type_slim              59934 non-null  bool
#  18  smokes_smoke                59934 non-null  bool
#  19  smokes_sometime_smoke       59934 non-null  bool
#  20  drinks_heavy                59934 non-null  bool
#  21  drinks_moderate             59934 non-null  bool
#  22  drinks_no_drinks            59934 non-null  bool
#  23  job_encoding                59934 non-null  int64
#  24  religion_no_religion        59934 non-null  bool
#  25  religion_religion           59934 non-null  bool
#  26  status_encoding             59934 non-null  int64
#  27  age_group                   59934 non-null  int64
#  28  diet_encoding               59934 non-null  int64
#  29  ethnicity_asian             59934 non-null  bool
#  30  ethnicity_black             59934 non-null  bool
#  31  ethnicity_hispanic / latin  59934 non-null  bool
#  32  ethnicity_mixed             59934 non-null  bool
#  33  ethnicity_other             59934 non-null  bool
#  34  ethnicity_white             59934 non-null  bool
#  35  dogs_encoding               59934 non-null  int64
#  36  cats_encoding               59934 non-null  int64
#  37  city                        59934 non-null  object
#  38  location_group_east_bay     59934 non-null  bool
#  39  location_group_north_bay    59934 non-null  bool
#  40  location_group_outside      59934 non-null  bool
#  41  location_group_sf           59934 non-null  bool
#  42  location_group_south_bay    59934 non-null  bool
#  43  churn                       59934 non-null  int64
# dtypes: bool(22), float64(2), int64(13), object(7)
# memory usage: 11.3+ MB

# %%
# 히트맵
cols = ['body_type_average', 'body_type_curvy', 'body_type_fit', 
        'body_type_slim', 'drinks_heavy','drinks_moderate',
        'drinks_no_drinks', 'smokes_sometime_smoke', 'smokes_smoke', 'churn']
plt.figure(figsize=(12, 10))
sns.heatmap(df[cols].corr(), annot=True, fmt=".2f", cmap="coolwarm", cbar=False)
# Out:
# <Axes: >

# %%
# 히트맵
cols = ['religion_no_religion','religion_religion','status_encoding',                   
        'age_group','diet_encoding','ethnicity_asian','ethnicity_black',                   
        'ethnicity_hispanic / latin','ethnicity_mixed','ethnicity_other',                   
        'ethnicity_white','dogs_encoding','cats_encoding', 'churn']
plt.figure(figsize=(12, 10))
sns.heatmap(df[cols].corr(), annot=True, fmt=".2f", cmap="coolwarm", cbar=False)
# Out:
# <Axes: >

# %%
# 히트맵
cols = ['location_group_east_bay', 'location_group_north_bay', 'location_group_outside',            
        'location_group_sf', 'location_group_south_bay', 'height', 'education', 'churn']
plt.figure(figsize=(12, 10))
sns.heatmap(df[cols].corr(), annot=True, fmt=".2f", cmap="coolwarm", cbar=False)
# Out:
# <Axes: >
